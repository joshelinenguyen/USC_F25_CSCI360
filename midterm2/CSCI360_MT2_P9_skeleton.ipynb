# %% [markdown]
# ### 9. Decision Trees as Interpretable Models

# %%
# Import

# Part (a)
# Install the ucimlrepo package 
# 'pip install ucimlrepo'
from ucimlrepo import fetch_ucirepo
import pandas as pd

# Part (c)
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Part (d)
from sklearn.tree import export_text

# Part (e)
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### (a) Download the car evaluation dataset from UCI Machine Learning Repository:
# https://archive.ics.uci.edu/dataset/19/car+evaluation.

# %%
# Source: the provided website
car_evaluation =  # <========== The easiest way is to use fetch_unirepo to fetch the dataset. You just need to find the repo id for this dataset.

print("Metadata:")
print(car_evaluation.metadata)

print("\nVariables:")
print(car_evaluation.variables)

# %% [markdown]
# #### (b) Use the first 80% data points in each class as training data and the rest as test data.

# %%
# Split the test

# %% [markdown]
# #### (c) Build a decision tree on the training set and plot it. Use gini index. If you are unsure about other hyperparameters of the algorithm, use sklearn’s default values.1

# %%
# Turn class labels into dummy variables

# %%
# Build & Fit


# Plot
feature_names =  # <===== Set feature name list
print('Feature Names:', feature_names)

plt.figure(figsize=(50, 25))
plot_tree() # <===== Fill in the arguments here
plt.show()

# %% [markdown]
# #### (d) Convert the decision rules into a set of IF-THEN rules.

# %%
text_rules = 

print(text_rules)

# %% [markdown]
# #### (e) Test the decision tree on your test set and report your test error.

# %%
test_accuracy = 
test_error = 

print("Test Accuracy: {:.5f}".format(test_accuracy))
print("Test Error: {:.5f}".format(test_error))
